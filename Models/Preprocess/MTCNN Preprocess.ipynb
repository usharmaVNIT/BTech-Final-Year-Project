# %%
import cv2
import os

# !pip install mtcnn
from mtcnn import MTCNN
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 1.5 MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.7.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.19.5)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_base = '/content/drive/MyDrive/Final year project/CNN_test/Images/train'
target_path = '/content/drive/MyDrive/Final year project/CNN_test/Cropped_Images_MTCNN/train'

#os.makedirs(target_path)

print(os.listdir(path_base))

detector = MTCNN()

def get_face(image):
    try:
        img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        y, x, h, w = detector.detect_faces(img)[0]['box'] 
        return True, image[x: x + w + 1, y: y + h + 1]
    except:
        return False, -1

i = 0
for folder in os.listdir(path_base):
    if folder == 'Bells':
      print('skip')
      continue
    target_class_folder = os.path.join(target_path, folder)
    os.makedirs(target_class_folder)
    folder_path = os.path.join(path_base, folder)
    for video in os.listdir(folder_path):
        video_path = os.path.join(folder_path, video)
        for frame in os.listdir(video_path):
            val, face = get_face(cv2.imread(os.path.join(video_path, frame)))
            if val:
                cv2.imwrite(os.path.join(target_class_folder, str(i) + ".jpg"), face)
                i += 1
# Out:
# ['Bells', 'Normal']
# skip
