# %%
from __future__ import print_function
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import BatchNormalization
from keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import pandas as pd
import numpy as np

# Reading feature vector from file
raw_data = pd.read_csv('input_final.csv')
raw_data.columns = ["F"+str(i) for i in range(1, len(raw_data.columns) + 1)]
# raw_data = raw_data.sample(frac=1)
print(raw_data.head())
# Pre-processing the data
features = raw_data.copy()
features = features.iloc[:,:-1]
labels = raw_data.iloc[:,-1:]

print(features.head())
print(labels.head())

features = np.array(features)
print(features)

#  Load the dataset
(x_train, y_train) = (features , labels)
(x_test, y_test) = (features , labels)

# # Display our data shape/dimensions
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# # Now we one hot encode outputs
# ytori = y_train
# num_classes = 2
# y_train = to_categorical(y_train, num_classes)
# y_test = to_categorical(y_test, num_classes)
# Out:
#            F1         F2         F3  ...         F79         F80  F81
# 0  117.022451  95.567316  77.702550  ...  563.138096  372.219223    1
# 1   40.962661  38.385066  32.198439  ...   66.484803   63.115706    1
# 2   42.924978  39.831538  34.121057  ...   63.761359   52.928770    1
# 3   36.683007  36.746411  30.111912  ...   57.602285   56.224384    1
# 4   38.713092  35.626802  30.483209  ...   57.926560   57.894936    1
#
# [5 rows x 81 columns]
#            F1         F2         F3  ...        F78         F79         F80
# 0  117.022451  95.567316  77.702550  ...  73.861975  563.138096  372.219223
# 1   40.962661  38.385066  32.198439  ...   9.607606   66.484803   63.115706
# 2   42.924978  39.831538  34.121057  ...  11.482237   63.761359   52.928770
# 3   36.683007  36.746411  30.111912  ...   6.235513   57.602285   56.224384
# 4   38.713092  35.626802  30.483209  ...   8.840690   57.926560   57.894936
#
# [5 rows x 80 columns]
#    F81
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# [[117.02245146  95.56731638  77.70254986 ...  73.86197523 563.13809625
#   372.21922322]
#  [ 40.96266103  38.38506583  32.19843903 ...   9.60760649  66.48480322
#    63.11570638]
#  [ 42.92497821  39.83153798  34.12105703 ...  11.48223703  63.76135877
#    52.92877004]
#  ...
#  [ 34.10758813  32.7355694   23.17637907 ...   5.25219521   9.20877033
#     5.07317251]
#  [ 58.46903113  56.2261979   38.34903171 ...  21.75321224  14.6413101
#    15.73188311]
#  [ 54.66687507  57.73432753  39.97113907 ...   5.73137076   8.99226143
#    12.38724838]]
# x_train shape: (70, 80)
# 70 train samples
# 70 test samples

# %%
# Initialize model
model = Sequential()


# 1 FC Layer
model.add(Dense(100))
# model.add(BatchNormalization())
model.add(Activation('relu'))
# model.add(Dropout(0.2))

# # 2 FC Layer
model.add(Dense(50))
# model.add(BatchNormalization())
model.add(Activation('relu'))
# model.add(Dropout(0.2))

# # 3 FC Layer
# model.add(Dense(128))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.5))


# # 4 FC Layer
# model.add(Dense(256))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.5))


# # 5 FC Layer
# model.add(Dense(128))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.5))


# 6 FC Layer
# model.add(Dense(7))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))


# 7 FC Layer
model.add(Dense(10))
# model.add(BatchNormalization())
model.add(Activation('relu'))
# model.add(Dropout(0.2))


# 8 FC Layer
model.add(Dense(1))
# model.add(BatchNormalization())
model.add(Activation('sigmoid'))


model.compile(loss = 'binary_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

#print(model.summary())

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
batch_size = 1
epochs = 50

checkpoint = ModelCheckpoint("Checkpoint.h5",
                             monitor="accuracy",
                             mode="max",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss',
                          min_delta = 0,
                          patience = 5, 
                          verbose = 1,
                          restore_best_weights = True)

callbacks = [checkpoint]

# %%
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks = callbacks,
          validation_data=(x_train, y_train))


scores = model.evaluate(x_train, y_train, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/50
# 70/70 [==============================] - 0s 3ms/step - loss: 1.2012 - accuracy: 0.8000 - val_loss: 1.0426 - val_accuracy: 0.7714
#
# Epoch 00001: accuracy improved from -inf to 0.80000, saving model to Checkpoint.h5
# Epoch 2/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.8000 - val_loss: 0.2544 - val_accuracy: 0.9000
#
# Epoch 00002: accuracy did not improve from 0.80000
# Epoch 3/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8571 - val_loss: 0.4744 - val_accuracy: 0.8143
#
# Epoch 00003: accuracy improved from 0.80000 to 0.85714, saving model to Checkpoint.h5
# Epoch 4/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8571 - val_loss: 0.2645 - val_accuracy: 0.8857
#
# Epoch 00004: accuracy did not improve from 0.85714
# Epoch 5/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3084 - accuracy: 0.8714 - val_loss: 0.2343 - val_accuracy: 0.9143
#
# Epoch 00005: accuracy improved from 0.85714 to 0.87143, saving model to Checkpoint.h5
# Epoch 6/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.9000 - val_loss: 1.4950 - val_accuracy: 0.7286
#
# Epoch 00006: accuracy improved from 0.87143 to 0.90000, saving model to Checkpoint.h5
# Epoch 7/50
# 70/70 [==============================] - 0s 3ms/step - loss: 1.2587 - accuracy: 0.7714 - val_loss: 0.3175 - val_accuracy: 0.8286
#
# Epoch 00007: accuracy did not improve from 0.90000
# Epoch 8/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8429 - val_loss: 0.2852 - val_accuracy: 0.8714
#
# Epoch 00008: accuracy did not improve from 0.90000
# Epoch 9/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.9000 - val_loss: 0.2948 - val_accuracy: 0.8714
#
# Epoch 00009: accuracy did not improve from 0.90000
# Epoch 10/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8286 - val_loss: 0.2399 - val_accuracy: 0.9000
#
# Epoch 00010: accuracy did not improve from 0.90000
# Epoch 11/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.8714 - val_loss: 0.2405 - val_accuracy: 0.9143
#
# Epoch 00011: accuracy did not improve from 0.90000
# Epoch 12/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3295 - accuracy: 0.8571 - val_loss: 0.4456 - val_accuracy: 0.8429
#
# Epoch 00012: accuracy did not improve from 0.90000
# Epoch 13/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.8571 - val_loss: 0.3410 - val_accuracy: 0.8571
#
# Epoch 00013: accuracy did not improve from 0.90000
# Epoch 14/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3125 - accuracy: 0.8571 - val_loss: 0.2253 - val_accuracy: 0.8857
#
# Epoch 00014: accuracy did not improve from 0.90000
# Epoch 15/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.9143 - val_loss: 0.3277 - val_accuracy: 0.8714
#
# Epoch 00015: accuracy improved from 0.90000 to 0.91429, saving model to Checkpoint.h5
# Epoch 16/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.8286 - val_loss: 0.2467 - val_accuracy: 0.8857
#
# Epoch 00016: accuracy did not improve from 0.91429
# Epoch 17/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2632 - accuracy: 0.9000 - val_loss: 0.2689 - val_accuracy: 0.8714
#
# Epoch 00017: accuracy did not improve from 0.91429
# Epoch 18/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3172 - accuracy: 0.8571 - val_loss: 0.4405 - val_accuracy: 0.8286
#
# Epoch 00018: accuracy did not improve from 0.91429
# Epoch 19/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3086 - accuracy: 0.9143 - val_loss: 0.2462 - val_accuracy: 0.8714
#
# Epoch 00019: accuracy did not improve from 0.91429
# Epoch 20/50
# 70/70 [==============================] - 0s 3ms/step - loss: 0.2692 - accuracy: 0.9143 - val_loss: 0.2780 - val_accuracy: 0.9000
#
# Epoch 00020: accuracy did not improve from 0.91429
# Epoch 21/50
# 70/70 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.9000 - val_loss: 1.6108 - val_accuracy: 0.7571
#
# Epoch 00021: accuracy did not improve from 0.91429
# Epoch 22/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.8286 - val_loss: 0.2473 - val_accuracy: 0.8857
#
# Epoch 00022: accuracy did not improve from 0.91429
# Epoch 23/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2614 - accuracy: 0.9143 - val_loss: 0.2993 - val_accuracy: 0.8714
#
# Epoch 00023: accuracy did not improve from 0.91429
# Epoch 24/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8714 - val_loss: 0.2081 - val_accuracy: 0.9286
#
# Epoch 00024: accuracy did not improve from 0.91429
# Epoch 25/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.9286 - val_loss: 0.2082 - val_accuracy: 0.9286
#
# Epoch 00025: accuracy improved from 0.91429 to 0.92857, saving model to Checkpoint.h5
# Epoch 26/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9429 - val_loss: 0.2799 - val_accuracy: 0.8571
#
# Epoch 00026: accuracy improved from 0.92857 to 0.94286, saving model to Checkpoint.h5
# Epoch 27/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.8857 - val_loss: 0.2408 - val_accuracy: 0.8857
#
# Epoch 00027: accuracy did not improve from 0.94286
# Epoch 28/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.9143 - val_loss: 0.1960 - val_accuracy: 0.9429
#
# Epoch 00028: accuracy did not improve from 0.94286
# Epoch 29/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.9143 - val_loss: 0.3770 - val_accuracy: 0.8571
#
# Epoch 00029: accuracy did not improve from 0.94286
# Epoch 30/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8571 - val_loss: 0.2146 - val_accuracy: 0.9143
#
# Epoch 00030: accuracy did not improve from 0.94286
# Epoch 31/50
# 70/70 [==============================] - 0s 3ms/step - loss: 0.4839 - accuracy: 0.8429 - val_loss: 0.4709 - val_accuracy: 0.7286
#
# Epoch 00031: accuracy did not improve from 0.94286
# Epoch 32/50
# 70/70 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.7571 - val_loss: 0.4056 - val_accuracy: 0.8571
#
# Epoch 00032: accuracy did not improve from 0.94286
# Epoch 33/50
# 70/70 [==============================] - 0s 2ms/step - loss: 1.0017 - accuracy: 0.7429 - val_loss: 0.2358 - val_accuracy: 0.9286
#
# Epoch 00033: accuracy did not improve from 0.94286
# Epoch 34/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3129 - accuracy: 0.8571 - val_loss: 0.2318 - val_accuracy: 0.9286
#
# Epoch 00034: accuracy did not improve from 0.94286
# Epoch 35/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3097 - accuracy: 0.8714 - val_loss: 0.2220 - val_accuracy: 0.9286
#
# Epoch 00035: accuracy did not improve from 0.94286
# Epoch 36/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2550 - accuracy: 0.8857 - val_loss: 0.3248 - val_accuracy: 0.8286
#
# Epoch 00036: accuracy did not improve from 0.94286
# Epoch 37/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.5317 - accuracy: 0.7571 - val_loss: 0.5340 - val_accuracy: 0.7000
#
# Epoch 00037: accuracy did not improve from 0.94286
# Epoch 38/50
# 70/70 [==============================] - 0s 2ms/step - loss: 2.6884 - accuracy: 0.7286 - val_loss: 0.5484 - val_accuracy: 0.7857
#
# Epoch 00038: accuracy did not improve from 0.94286
# Epoch 39/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.8000 - val_loss: 0.3110 - val_accuracy: 0.8714
#
# Epoch 00039: accuracy did not improve from 0.94286
# Epoch 40/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3581 - accuracy: 0.8714 - val_loss: 0.2837 - val_accuracy: 0.8714
#
# Epoch 00040: accuracy did not improve from 0.94286
# Epoch 41/50
# 70/70 [==============================] - 0s 3ms/step - loss: 0.2878 - accuracy: 0.8714 - val_loss: 0.3190 - val_accuracy: 0.7714
#
# Epoch 00041: accuracy did not improve from 0.94286
# Epoch 42/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8571 - val_loss: 0.3012 - val_accuracy: 0.8571
#
# Epoch 00042: accuracy did not improve from 0.94286
# Epoch 43/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.8714 - val_loss: 0.2262 - val_accuracy: 0.9000
#
# Epoch 00043: accuracy did not improve from 0.94286
# Epoch 44/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2692 - accuracy: 0.8714 - val_loss: 0.2444 - val_accuracy: 0.9000
#
# Epoch 00044: accuracy did not improve from 0.94286
# Epoch 45/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 0.8857 - val_loss: 0.2130 - val_accuracy: 0.9286
#
# Epoch 00045: accuracy did not improve from 0.94286
# Epoch 46/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.8857 - val_loss: 0.2078 - val_accuracy: 0.9286
#
# Epoch 00046: accuracy did not improve from 0.94286
# Epoch 47/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.9143 - val_loss: 0.2863 - val_accuracy: 0.8857
#
# Epoch 00047: accuracy did not improve from 0.94286
# Epoch 48/50
# 70/70 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.8714 - val_loss: 0.1987 - val_accuracy: 0.9429
#
# Epoch 00048: accuracy did not improve from 0.94286
# Epoch 49/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2237 - accuracy: 0.9286 - val_loss: 0.2169 - val_accuracy: 0.8857
#
# Epoch 00049: accuracy did not improve from 0.94286
# Epoch 50/50
# 70/70 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9000 - val_loss: 0.2064 - val_accuracy: 0.9429
#
# Epoch 00050: accuracy did not improve from 0.94286
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2064 - accuracy: 0.9429
# Test loss: 0.20644114911556244
# Test accuracy: 0.9428571462631226

# %%
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
nmodel = keras.models.load_model('Checkpoint.h5')

# %%
print(nmodel.summary())
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_57 (Dense)             (1, 10)                   20
# _________________________________________________________________
# activation_57 (Activation)   (1, 10)                   0
# _________________________________________________________________
# dropout_40 (Dropout)         (1, 10)                   0
# _________________________________________________________________
# dense_58 (Dense)             (1, 5)                    55
# _________________________________________________________________
# activation_58 (Activation)   (1, 5)                    0
# _________________________________________________________________
# dropout_41 (Dropout)         (1, 5)                    0
# _________________________________________________________________
# dense_59 (Dense)             (1, 1)                    6
# _________________________________________________________________
# activation_59 (Activation)   (1, 1)                    0
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________
# None
